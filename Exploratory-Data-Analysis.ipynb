# %%
#Step 1
#Read the file train.csv into Python and print a few rows.

import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns


train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Step 2
#Calculate the number of surviving/non-surviving passengers and display it as a bar plot.
train['Survived'].value_counts().to_frame()
# Out:
#    Survived
# 0       549
# 1       342

# %%
sns.countplot(x='Survived', data=train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#Step 3
#Calculate the proportion of surviving 1st class passengers with regards to the total number of 1st class passengers.

train.loc[train['Pclass']==1]['Survived'].value_counts(normalize=True)
# Out:
# 1    0.62963
# 0    0.37037
# Name: Survived, dtype: float64

# %%
#Step 4
#Calculate the proportion of surviving 1st class passengers with regards to the total number of 1st class passengers.

sns.countplot(x='Sex', hue='Pclass', data=train)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#Step 5
#Create a histogram showing the age distribution of passengers. Compare surviving/non-surviving passengers.

sns.histplot(x ='Age', hue = 'Survived', data=train, multiple ="dodge")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#Step 6
#Calculate the average age for survived and drowned passengers separately.


train.loc[train['Survived']==1]['Age'].mean()
# Out:
# 28.343689655172415

# %%
train.loc[train['Survived']==0]['Age'].mean()
# Out:
# 30.62617924528302

# %%
#Step 7
#Replace missing age values by the mean age.

train['Age'].isnull().sum()
# Out:
# 177

# %%
train['Age'].fillna(train['Age'].mean(), inplace = True)

# %%
#Step 8
#Create a table counting the number of surviving/dead passengers separately for 1st/2nd/3rd class and male/female
S=train.loc[train['Survived']==1]
U=train.loc[train['Survived']==0]
S
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
U
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
train.groupby(['Pclass', 'Survived', 'Sex' ]).count()
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived Sex
# 1      0        female            3     3    3      3      3       3     3
#                 male             77    77   77     77     77      77    77
#        1        female           91    91   91     91     91      91    91
#                 male             45    45   45     45     45      45    45
# 2      0        female            6     6    6      6      6       6     6
#                 male             91    91   91     91     91      91    91
#        1        female           70    70   70     70     70      70    70
#                 male             17    17   17     17     17      17    17
# 3      0        female           72    72   72     72     72      72    72
#                 male            300   300  300    300    300     300   300
#        1        female           72    72   72     72     72      72    72
# ...

# %%
sns.barplot(data=train, x='Sex', y= 'Survived', hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
grid = sns.FacetGrid(data=train, col='Pclass', hue='Sex', palette=['#FFADB9', '#3BCCDA'] )
grid.map_dataframe(sns.scatterplot, x='Survived', y='Sex')
grid.add_legend()

grid.set_xlabels("Survived")
grid.set_ylabels("Sex")
sns.despine()
